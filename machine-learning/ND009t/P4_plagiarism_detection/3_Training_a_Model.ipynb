# %%
import json
import os
import re
from typing import Tuple

import boto3
import numpy as np
import pandas as pd
import sagemaker
from botocore.exceptions import ClientError
from deepdiff import DeepHash
from dotenv import load_dotenv
from sagemaker.sklearn import SKLearn
from sklearn.metrics import accuracy_score

from helpers import OUTPUT_DIR, S3_FEATURE_DIR, S3_MODEL_DIR

load_dotenv(override=True)

# session and role
sagemaker_session = sagemaker.Session()
role = os.environ.get('SAGEMAKER_EXECUTION_ROLE') or sagemaker.get_execution_role()

# create an S3 bucket
bucket = sagemaker_session.default_bucket()

# these are the largest training / deploy instances available in aws educate
TRAIN_INSTANCE = 'ml.m5.large'
DEPLOY_INSTANCE = 'ml.m5.large'

# %% [markdown]
# # Plagiarism Detection Model
#
# Now that you've created training and test data, you are ready to define and train a model. Your goal in this notebook, will be to train a binary classification model that learns to label an answer file as either plagiarized or not, based on the features you provide the model.
#
# This task will be broken down into a few discrete steps:
#
# * Upload your data to S3.
# * Define a binary classification model and a training script.
# * Train your model and deploy it.
# * Evaluate your deployed classifier and answer some questions about your approach.
#
# To complete this notebook, you'll have to complete all given exercises and answer all the questions in this notebook.
# > All your tasks will be clearly labeled **EXERCISE** and questions as **QUESTION**.
#
# It will be up to you to explore different classification models and decide on a model that gives you the best performance for this dataset.
#
# ---

# %% [markdown]
# ## Load Data to S3
#
# In the last notebook, you should have created two files: a `training.csv` and `test.csv` file with the features and class labels for the given corpus of plagiarized/non-plagiarized text data.
#
# >The below cells load in some AWS SageMaker libraries and creates a default bucket. After creating this bucket, you can upload your locally stored data to S3.
#
# Save your train and test `.csv` feature files, locally. To do this you can run the second notebook "2_Plagiarism_Feature_Engineering" in SageMaker or you can manually upload your files to this notebook using the upload icon in Jupyter Lab. Then you can upload local files to S3 by using `sagemaker_session.upload_data` and pointing directly to where the training data is saved.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Moved to top for easier execution while iterating on notebook
# Out:
# "\nDON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE\n"

# %% [markdown]
# ## EXERCISE: Upload your training data to S3
#
# Specify the `data_dir` where you've saved your `train.csv` file. Decide on a descriptive `prefix` that defines where your data will be uploaded in the default S3 bucket. Finally, create a pointer to your training data by calling `sagemaker_session.upload_data` and passing in the required parameters. It may help to look at the [Session documentation](https://sagemaker.readthedocs.io/en/stable/session.html#sagemaker.session.Session.upload_data) or previous SageMaker code examples.
#
# You are expected to upload your entire directory. Later, the training script will only access the `train.csv` file.

# %%
# should be the name of directory you created to save your features data

data_to_try = ['all-features']
prefix = None
data_desc = None

for data_desc in data_to_try:
    # set prefix, a descriptive name for a directory
    prefix = S3_FEATURE_DIR / data_desc

    # upload all data to S3
    sagemaker_session.upload_data(path=str(OUTPUT_DIR / data_desc), key_prefix=prefix)

# %% [markdown]
# ### Test cell
#
# Test that your data has been successfully uploaded. The below cell prints out the items in your S3 bucket and will throw an error if it is empty. You should see the contents of your `data_dir` and perhaps some checkpoints. If you see any other files listed, then you may have some old model files that you can delete via the S3 console (though, additional files shouldn't affect the performance of model developed in this notebook).

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# confirm that data is in S3 bucket
empty_check = []
for obj in boto3.resource('s3').Bucket(bucket).objects.filter(Prefix=str(prefix)):
    empty_check.append(obj.key)
    print(obj.key)

assert len(empty_check) != 0, 'S3 bucket is empty.'
print('Test passed!')
# Out:
# P4_plagiarism_detection/feature-data/all-features/test.csv
# P4_plagiarism_detection/feature-data/all-features/train.csv
# Test passed!

# %% [markdown]
# ---
#
# # Modeling
#
# Now that you've uploaded your training data, it's time to define and train a model!
#
# The type of model you create is up to you. For a binary classification task, you can choose to go one of three routes:
# * Use a built-in classification algorithm, like LinearLearner.
# * Define a custom Scikit-learn classifier, a comparison of models can be found [here](https://scikit-learn.org/stable/auto_examples/classification/plot_classifier_comparison.html).
# * Define a custom PyTorch neural network classifier.
#
# It will be up to you to test out a variety of models and choose the best one. Your project will be graded on the accuracy of your final model.
#
# ---
#
# ## EXERCISE: Complete a training script
#
# To implement a custom classifier, you'll need to complete a `train.py` script. You've been given the folders `source_sklearn` and `source_pytorch` which hold starting code for a custom Scikit-learn model and a PyTorch model, respectively. Each directory has a `train.py` training script. To complete this project **you only need to complete one of these scripts**; the script that is responsible for training your final model.
#
# A typical training script:
# * Loads training data from a specified directory
# * Parses any training & model hyperparameters (ex. nodes in a neural network, training epochs, etc.)
# * Instantiates a model of your design, with any specified hyperparams
# * Trains that model
# * Finally, saves the model so that it can be hosted/deployed, later
#
# ### Defining and training a model
# Much of the training script code is provided for you. Almost all of your work will be done in the `if __name__ == '__main__':` section. To complete a `train.py` file, you will:
# 1. Import any extra libraries you need
# 2. Define any additional model training hyperparameters using `parser.add_argument`
# 2. Define a model in the `if __name__ == '__main__':` section
# 3. Train the model in that same section
#
# Below, you can use `!pygmentize` to display an existing `train.py` file. Read through the code; all of your tasks are marked with `TODO` comments.
#
# **Note: If you choose to create a custom PyTorch model, you will be responsible for defining the model in the `model.py` file,** and a `predict.py` file is provided. If you choose to use Scikit-learn, you only need a `train.py` file; you may import a classifier from the `sklearn` library.

# %%
# directory can be changed to: source_sklearn or source_pytorch
# !pygmentize sagemaker_container/train_and_deploy.py
# Out:
# from __future__ import print_function
#
# import json
# import os
# from time import time
#
# import joblib
# import pandas as pd
# from sklearn.ensemble import AdaBoostClassifier
# from sklearn.metrics import classification_report
# from sklearn.naive_bayes import GaussianNB
# from sklearn.svm import SVC
# from sklearn.tree import DecisionTreeClassifier
#
# RANDOM_SEED = 28
# CLASSIFIERS = {
#     'SVC': SVC,
#     'GaussianNB': GaussianNB,
#     'DecisionTreeClassifier': DecisionTreeClassifier,
#     'AdaBoostClassifier': AdaBoostClassifier,
# }
#
#
# # Provided model load function
# def model_fn(model_dir):
#     """Load model from the model_dir. This is the same model that is saved
#     in the main if statement.
#     """
#     print("Loading model.")
#
#     # load using joblib
#     model = joblib.load(os.path.join(model_dir, "model.joblib"))
#     print("Done loading model.")
#
#     return model
#
#
# def get_data_by_desc(data_desc):
#     test_data = pd.read_csv(os.path.join(data_desc, 'test.csv'), header=None, names=None)
#     test_features = test_data.iloc[:, 1:]
#     test_labels = test_data.iloc[:, 0]
#
#     train_data = pd.read_csv(os.path.join(data_desc, 'train.csv'), header=None, names=None)
#     train_features = train_data.iloc[:, 1:]
#     train_labels = train_data.iloc[:, 0]
#
#     return train_features, train_labels, test_features, test_labels
#
#
# if __name__ == '__main__':
#     # All of the model parameters and training parameters are sent as arguments
#     # when this script is executed, during a training job
#
#     # Here we set up an argument parser to easily access the parameters
#
#     print('environment: ', os.environ)
#
#     # SageMaker parameters, like the directories for training data and saving models; set automatically
#     # Do not need to change
#     output_dir = os.environ['SM_OUTPUT_DATA_DIR']
#     model_dir = os.environ['SM_MODEL_DIR']
#     data_dir = os.environ['SM_CHANNEL_TRAINING']
#
#     # --- Your code here --- ##
#     # hyperparameters sent by the client are passed as command-line arguments to the script.
#     with open(os.environ['SM_INPUT_TRAINING_CONFIG_FILE'], 'r') as f:
#         print('loading hyperparameters')
#         hyperparameters = json.load(f)
#         print('hyperparameters initial:', json.dumps(hyperparameters))
#         for param in list(hyperparameters):
#             # delete all sagemaker hyperparameters
#             value = hyperparameters.get(param)
#             if param.startswith('sagemaker_'):
#                 del hyperparameters[param]
#             # remove extra `"` added to params
#             elif isinstance(value, str):
#                 hyperparameters[param] = value.strip('"')
#                 # make true and false True and False
#                 if value.lower() == 'true':
#                     hyperparameters[param] = True
#                 elif value.lower() == 'false':
#                     hyperparameters[param] = False
#                 # convert integers
#                 elif value.isdigit():
#                     hyperparameters[param] = int(value)
#                 # convert float
#                 elif value.replace('.', '', 1).isdigit():
#                     hyperparameters[param] = float(value)
#
#         print('hyperparameters:', json.dumps(hyperparameters))
#
#     # Read in csv training file
#     train_features, train_labels, test_features, test_labels = get_data_by_desc(data_dir)
#
#     # Define the model
#     classifier = hyperparameters['classifier']
#     del hyperparameters['classifier']
#     classifier_class = CLASSIFIERS.get(classifier)
#     if not classifier_class:
#         raise ValueError(f'classifier {classifier} not found in CLASSIFIERS, import and add it')
#
#     print('hyperparameters passed to model: ', json.dumps(hyperparameters))
#     model = classifier_class(**hyperparameters)
#
#     # for models that can use multiple CPUs use them all
#     if hasattr(model, 'n_jobs'):
#         model.n_jobs = -1
#     if hasattr(model, 'random_state'):
#         model.random_state = RANDOM_SEED
#
#     # Train the model
#     model.fit(train_features, train_labels)
#
#     # Evaluate the model
#     # - inference speed
#     t = time()
#     predict_labels = model.predict(test_features)
#     inference_speed_per_record = (time() - t) / len(predict_labels)
#
#     # - accuracy score
#     # - recall
#     # - precision
#     report = classification_report(test_labels, predict_labels, output_dict=True)
#     print('classification_report: ', classifier_class)
#     # to measure metrics just print the variables separated by `;`
#     print(f"accuracy: {report['accuracy']}; "
#           f"recall: {report['1.0']['recall']}; "
#           f"precision: {report['1.0']['precision']}; "
#           f"f1_score: {report['1.0']['f1-score']}; "
#           f"inference_speed: {inference_speed_per_record}")
#
#     classifier_performance = {
#         "classifier": type(model).__name__,
#         "data_description": data_dir,
#         "params": model.get_params(),
#         "accuracy": report['accuracy'],
#         "recall": report['1.0']['recall'],
#         "precision": report['1.0']['precision'],
#         "f1_score": report['1.0']['f1-score'],
#         "inference_speed": inference_speed_per_record,
#     }
#     # save test metrics with model
#     with open(os.path.join(output_dir, 'performance.json'), 'w') as f:
#         json.dump(classifier_performance, f)
#
#     # --- End of your code  --- ##
#
#     # Save the trained model
#     joblib.dump(model, os.path.join(model_dir, "model.joblib"))

# %% [markdown]
# ### Provided code
#
# If you read the code above, you can see that the starter code includes a few things:
# * Model loading (`model_fn`) and saving code
# * Getting SageMaker's default hyperparameters
# * Loading the training data by name, `train.csv` and extracting the features and labels, `train_x`, and `train_y`
#
# If you'd like to read more about model saving with [joblib for sklearn](https://scikit-learn.org/stable/modules/model_persistence.html) or with [torch.save](https://pytorch.org/tutorials/beginner/saving_loading_models.html), click on the provided links.

# %% [markdown]
# ---
# # Create an Estimator
#
# When a custom model is constructed in SageMaker, an entry point must be specified. This is the Python file which will be executed when the model is trained; the `train.py` function you specified above. To run a custom training script in SageMaker, construct an estimator, and fill in the appropriate constructor arguments:
#
# * **entry_point**: The path to the Python script SageMaker runs for training and prediction.
# * **source_dir**: The path to the training script directory `source_sklearn` OR `source_pytorch`.
# * **entry_point**: The path to the Python script SageMaker runs for training and prediction.
# * **source_dir**: The path to the training script directory `train_sklearn` OR `train_pytorch`.
# * **entry_point**: The path to the Python script SageMaker runs for training.
# * **source_dir**: The path to the training script directory `train_sklearn` OR `train_pytorch`.
# * **role**: Role ARN, which was specified, above.
# * **train_instance_count**: The number of training instances (should be left at 1).
# * **train_instance_type**: The type of SageMaker instance for training. Note: Because Scikit-learn does not natively support GPU training, Sagemaker Scikit-learn does not currently support training on GPU instance types.
# * **sagemaker_session**: The session used to train on Sagemaker.
# * **hyperparameters** (optional): A dictionary `{'name':value, ..}` passed to the train function as hyperparameters.
#
# Note: For a PyTorch model, there is another optional argument **framework_version**, which you can set to the latest version of PyTorch, `1.0`.
#
# ## EXERCISE: Define a Scikit-learn or PyTorch estimator
#
# To import your desired estimator, use one of the following lines:
# ```
# from sagemaker.sklearn.estimator import SKLearn
# ```
# ```
# from sagemaker.pytorch import PyTorch
# ```

# %%
# your import and estimator code, here
def build_name_from_array(model_array):
    model_name = '-'.join(model_array)
    model_name = re.sub(r"[^-a-zA-Z0-9]+", '-', model_name).strip('-')
    return re.sub(r"--+", '-', model_name)


def build_model_name(data_desc, classifier, hyperparams, count) -> str:
    hyperparams_json = json.dumps(hyperparams, sort_keys=True, ensure_ascii=True)
    model_name = build_name_from_array([
        data_desc,
        classifier,
        hyperparams_json,
        str(count),
    ])
    if len(model_name) > 63:
        hyperparams_hash = str(DeepHash(hyperparams_json)[hyperparams_json])[:8]
        model_name = build_name_from_array([
            data_desc,
            classifier,
            hyperparams_hash,
            str(count),
        ])
        if len(model_name) > 63:
            # this will error on the server, error fast
            raise ValueError(f'generated model name is too long: {model_name}')
    return model_name


def build_and_train_estimator(
    data_desc: str,
    classifier: str,
    count: int = 1,
    wait: bool = False,
    **hyperparams: object
) -> Tuple[SKLearn, str]:
    """
    Creates or returns an existing sagemaker training job

    :param data_desc: name of data to use (unique)
    :param classifier: name of sklearn classifier
    :param count: cache buster
    :param wait: waits on job, useful for debugging
    :param hyperparams: hyperparameters for the model
    :return: estimator | None
    """
    model_name = build_model_name(data_desc, classifier, hyperparams, count)
    print('model_name', model_name)

    # check if model has already been built on this data
    #  if it has check if it's finished and attach
    try:
        import boto3
        client = boto3.client('sagemaker')
        response = client.describe_training_job(
            TrainingJobName=model_name
        )
        if wait or response['TrainingJobStatus'] in ['Completed', 'Failed']:
            return SKLearn.attach(model_name), model_name
        else:
            raise Warning(f'{model_name} isn\'t finished training yet')
    except ClientError:
        pass

    output_location = f's3://{bucket}/{S3_MODEL_DIR / data_desc}'
    estimator = SKLearn(
        'train_and_deploy.py',
        source_dir='sagemaker_container',
        code_location=output_location,
        output_path=output_location,
        train_instance_type=TRAIN_INSTANCE,
        framework_version='0.23-1',
        role=role,
        hyperparameters={
            'classifier': classifier,
            **hyperparams
        })

    estimator.fit(f's3://{bucket}/{S3_FEATURE_DIR / data_desc}', wait=wait, job_name=model_name)

    return estimator, model_name

# %% [markdown]
# ## EXERCISE: Train the estimator
#
# Train your estimator on the training data stored in S3. This should create a training job that you can monitor in your SageMaker console.

# %%
# Train your estimator on S3 training data
build_and_train_estimator('all-features', 'SVC')
# Out:
# model_name all-features-SVC-1
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:48:55 Starting - Preparing the instances for training
# 2020-08-06 18:48:55 Downloading - Downloading input data
# 2020-08-06 18:48:55 Training - Training image download completed. Training in progress.
# 2020-08-06 18:48:55 Uploading - Uploading generated training model
# 2020-08-06 18:48:55 Completed - Training job completed2020-08-06 18:48:27,657 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:48:27,659 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:27,669 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:48:27,918 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:48:29,249 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:29,260 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:29,270 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:29,281 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "classifier": "SVC"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-SVC-1",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-1/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"SVC"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-1/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","SVC"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_CLASSIFIER=SVC
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier SVC
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-2-73-123.ec2.internal', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'DMLC_INTERFACE': 'eth0', 'TRAINING_JOB_NAME': 'all-features-SVC-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/caedf99e-8f50-4f01-8d76-70e9902c0823', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-svc-1', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/5daa571c-2468-4578-9db7-0c2e4b28e61c', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/5daa571c-2468-4578-9db7-0c2e4b28e61c', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-SVC-1', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"SVC"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-1/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","SVC"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_CLASSIFIER': 'SVC', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages', 'KMP_INIT_AT_FORK': 'FALSE', 'KMP_DUPLICATE_LIB_OK': 'True'})
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "classifier": "\"SVC\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-SVC-1\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-1/source/sourcedir.tar.gz\""}
# hyperparameters: {"classifier": "SVC"}
# data_desc training
# hyperparameters passed to model:  {}
# classification_report:  <class 'sklearn.svm._classes.SVC'>
# accuracy: 0.88; recall: 0.8; precision: 1.0; f1_score: 0.888888888888889; inference_speed: 5.190849304199219e-05
# 2020-08-06 18:48:30,507 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 136
# Billable seconds: 136
# (<sagemaker.sklearn.estimator.SKLearn at 0x7f8c5b9e9f10>, 'all-features-SVC-1')

# %%
# GaussianNB
for data_desc in data_to_try:
    build_and_train_estimator(data_desc, 'GaussianNB')
# Out:
# model_name all-features-GaussianNB-1
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:49:24 Starting - Preparing the instances for training
# 2020-08-06 18:49:24 Downloading - Downloading input data
# 2020-08-06 18:49:24 Training - Training image download completed. Training in progress.
# 2020-08-06 18:49:24 Uploading - Uploading generated training model
# 2020-08-06 18:49:24 Completed - Training job completed2020-08-06 18:48:42,000 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:48:42,002 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:42,011 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:49:11,357 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:49:12,703 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:49:12,713 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:49:12,723 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:49:12,733 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "classifier": "GaussianNB"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-GaussianNB-1",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-GaussianNB-1/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"GaussianNB"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-GaussianNB-1/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"GaussianNB"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-GaussianNB-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-GaussianNB-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","GaussianNB"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_CLASSIFIER=GaussianNB
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier GaussianNB
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-215-236.ec2.internal', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-gaussiannb-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/fdbbbc24-102c-43da-a62f-395f3a9a4190', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'DMLC_INTERFACE': 'eth0', 'TRAINING_JOB_NAME': 'all-features-GaussianNB-1', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/08bba76b-0f01-4fc0-8138-8e9d02b7c86e', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/08bba76b-0f01-4fc0-8138-8e9d02b7c86e', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-GaussianNB-1', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"GaussianNB"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-GaussianNB-1/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"GaussianNB"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-GaussianNB-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-GaussianNB-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","GaussianNB"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_CLASSIFIER': 'GaussianNB', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages', 'KMP_INIT_AT_FO ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "classifier": "\"GaussianNB\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-GaussianNB-1\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-GaussianNB-1/source/sourcedir.tar.gz\""}
# hyperparameters: {"classifier": "GaussianNB"}
# data_desc training
# hyperparameters passed to model:  {}
# classification_report:  <class 'sklearn.naive_bayes.GaussianNB'>
# accuracy: 0.88; recall: 0.8666666666666667; precision: 0.9285714285714286; f1_score: 0.896551724137931; inference_speed: 5.2976608276367185e-05
# 2020-08-06 18:49:14,052 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 110
# Billable seconds: 110

# %%
# SVC
for data_desc in data_to_try:
    for kernel in [
        'rbf',
        'linear',
        # 'poly',
        'sigmoid',
    ]:
        build_and_train_estimator(data_desc, 'SVC', kernel=kernel)
    build_and_train_estimator(data_desc, 'SVC', kernel='poly', count=2)
# Out:
# model_name all-features-SVC-kernel-rbf-1
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:48:32 Starting - Preparing the instances for training
# 2020-08-06 18:48:32 Downloading - Downloading input data
# 2020-08-06 18:48:32 Training - Training image download completed. Training in progress.
# 2020-08-06 18:48:32 Uploading - Uploading generated training model
# 2020-08-06 18:48:32 Completed - Training job completed2020-08-06 18:48:15,010 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:48:15,012 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:15,022 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:48:15,503 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:48:16,950 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:20,001 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:20,012 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:20,022 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "kernel": "rbf",
#         "classifier": "SVC"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-SVC-kernel-rbf-1",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-rbf-1/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"SVC","kernel":"rbf"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-rbf-1/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"rbf"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-rbf-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-rbf-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","SVC","--kernel","rbf"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_KERNEL=rbf
# SM_HP_CLASSIFIER=SVC
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier SVC --kernel rbf
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-243-234.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/142549c1-72d5-40c2-9b39-9e5e2be8b568', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/4a4aad50-9b99-492f-ba95-0f03865a9b20', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'DMLC_INTERFACE': 'eth0', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-svc-kernel-rbf-1', 'TRAINING_JOB_NAME': 'all-features-SVC-kernel-rbf-1', 'AWS_REGION': 'us-east-1', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/4a4aad50-9b99-492f-ba95-0f03865a9b20', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-SVC-kernel-rbf-1', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"SVC","kernel":"rbf"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-rbf-1/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"rbf"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-rbf-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-rbf-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","SVC","--kernel","rbf"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_KERNEL': 'rbf', 'SM_HP_CLASSIFIER': 'SVC', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "kernel": "\"rbf\"", "classifier": "\"SVC\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-SVC-kernel-rbf-1\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-rbf-1/source/sourcedir.tar.gz\""}
# hyperparameters: {"kernel": "rbf", "classifier": "SVC"}
# data_desc training
# hyperparameters passed to model:  {"kernel": "rbf"}
# classification_report:  <class 'sklearn.svm._classes.SVC'>
# accuracy: 0.88; recall: 0.8; precision: 1.0; f1_score: 0.888888888888889; inference_speed: 5.188941955566406e-05
# 2020-08-06 18:48:21,428 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 86
# Billable seconds: 86
# model_name all-features-SVC-kernel-linear-1
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:49:07 Starting - Preparing the instances for training
# 2020-08-06 18:49:07 Downloading - Downloading input data
# 2020-08-06 18:49:07 Training - Training image download completed. Training in progress.
# 2020-08-06 18:49:07 Uploading - Uploading generated training model
# 2020-08-06 18:49:07 Completed - Training job completed2020-08-06 18:48:49,619 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:48:49,620 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:49,629 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:48:49,902 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:48:51,225 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:54,277 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:54,287 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:48:54,297 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "kernel": "linear",
#         "classifier": "SVC"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-SVC-kernel-linear-1",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-linear-1/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"SVC","kernel":"linear"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-linear-1/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"linear"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-linear-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-linear-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","SVC","--kernel","linear"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_KERNEL=linear
# SM_HP_CLASSIFIER=SVC
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier SVC --kernel linear
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-231-161.ec2.internal', 'AWS_REGION': 'us-east-1', 'TRAINING_JOB_NAME': 'all-features-SVC-kernel-linear-1', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/a5e96995-a25b-4b88-a50c-042577428540', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/a5e96995-a25b-4b88-a50c-042577428540', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'DMLC_INTERFACE': 'eth0', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-svc-kernel-linear-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/c0e93996-464a-4b19-82f7-30d67b52e772', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-SVC-kernel-linear-1', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"SVC","kernel":"linear"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-linear-1/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"linear"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-linear-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-linear-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","SVC","--kernel","linear"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_KERNEL': 'linear', 'SM_HP_CLASSIFIER': 'SVC', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7 ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "kernel": "\"linear\"", "classifier": "\"SVC\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-SVC-kernel-linear-1\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-linear-1/source/sourcedir.tar.gz\""}
# hyperparameters: {"kernel": "linear", "classifier": "SVC"}
# data_desc training
# hyperparameters passed to model:  {"kernel": "linear"}
# classification_report:  <class 'sklearn.svm._classes.SVC'>
# accuracy: 0.88; recall: 0.8; precision: 1.0; f1_score: 0.888888888888889; inference_speed: 4.95147705078125e-05
# 2020-08-06 18:48:55,462 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 86
# Billable seconds: 86
# model_name all-features-SVC-kernel-sigmoid-1
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:53:07 Starting - Preparing the instances for training
# 2020-08-06 18:53:07 Downloading - Downloading input data
# 2020-08-06 18:53:07 Training - Training image download completed. Training in progress.
# 2020-08-06 18:53:07 Uploading - Uploading generated training model
# 2020-08-06 18:53:07 Completed - Training job completed2020-08-06 18:52:55,200 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:52:55,202 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:52:55,211 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:52:55,466 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:52:56,802 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:52:56,815 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:52:56,826 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:52:56,836 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "kernel": "sigmoid",
#         "classifier": "SVC"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-SVC-kernel-sigmoid-1",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-sigmoid-1/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"SVC","kernel":"sigmoid"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-sigmoid-1/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"sigmoid"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-sigmoid-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-sigmoid-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","SVC","--kernel","sigmoid"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_KERNEL=sigmoid
# SM_HP_CLASSIFIER=SVC
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier SVC --kernel sigmoid
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-129-191.ec2.internal', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/b94f64c5-cfe3-421f-b077-b61b8481dc4e', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/01e62454-5a26-4265-a002-2232df465a2d', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'AWS_REGION': 'us-east-1', 'DMLC_INTERFACE': 'eth0', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'all-features-SVC-kernel-sigmoid-1', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-svc-kernel-sigmoid-1', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/01e62454-5a26-4265-a002-2232df465a2d', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-SVC-kernel-sigmoid-1', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"SVC","kernel":"sigmoid"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-sigmoid-1/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"sigmoid"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-sigmoid-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-sigmoid-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","SVC","--kernel","sigmoid"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_KERNEL': 'sigmoid', 'SM_HP_CLASSIFIER': 'SVC', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "kernel": "\"sigmoid\"", "classifier": "\"SVC\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-SVC-kernel-sigmoid-1\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-sigmoid-1/source/sourcedir.tar.gz\""}
# hyperparameters: {"kernel": "sigmoid", "classifier": "SVC"}
# data_desc training
# hyperparameters passed to model:  {"kernel": "sigmoid"}
# classification_report:  <class 'sklearn.svm._classes.SVC'>
# accuracy: 0.32; recall: 0.4; precision: 0.42857142857142855; f1_score: 0.4137931034482759; inference_speed: 5.3625106811523435e-05
# 2020-08-06 18:52:57,924 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 84
# Billable seconds: 84
# model_name all-features-SVC-kernel-poly-2
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:42:58 Starting - Preparing the instances for training
# 2020-08-06 18:42:58 Downloading - Downloading input data
# 2020-08-06 18:42:58 Training - Training image download completed. Training in progress.
# 2020-08-06 18:42:58 Uploading - Uploading generated training model
# 2020-08-06 18:42:58 Completed - Training job completed2020-08-06 18:42:44,939 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:42:44,941 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:42:44,950 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:42:45,231 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:42:46,598 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:42:47,260 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:42:47,270 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:42:47,281 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "kernel": "poly",
#         "classifier": "SVC"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-SVC-kernel-poly-2",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-poly-2/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"SVC","kernel":"poly"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-poly-2/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"poly"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-poly-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-poly-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","SVC","--kernel","poly"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_KERNEL=poly
# SM_HP_CLASSIFIER=SVC
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier SVC --kernel poly
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-92-41.ec2.internal', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'AWS_REGION': 'us-east-1', 'TRAINING_JOB_NAME': 'all-features-SVC-kernel-poly-2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/17b10693-77f8-4564-9107-6b478c2a8674', 'DMLC_INTERFACE': 'eth0', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-svc-kernel-poly-2', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/d29e7f4f-9881-483b-8d93-28235d7edee0', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/17b10693-77f8-4564-9107-6b478c2a8674', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-SVC-kernel-poly-2', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"SVC","kernel":"poly"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-poly-2/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"SVC","kernel":"poly"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-SVC-kernel-poly-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-poly-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","SVC","--kernel","poly"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_KERNEL': 'poly', 'SM_HP_CLASSIFIER': 'SVC', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/pytho ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "kernel": "\"poly\"", "classifier": "\"SVC\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-SVC-kernel-poly-2\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-SVC-kernel-poly-2/source/sourcedir.tar.gz\""}
# hyperparameters: {"kernel": "poly", "classifier": "SVC"}
# data_desc training
# hyperparameters passed to model:  {"kernel": "poly"}
# classification_report:  <class 'sklearn.svm._classes.SVC'>
# accuracy: 0.88; recall: 0.8; precision: 1.0; f1_score: 0.888888888888889; inference_speed: 5.316734313964844e-05
# 2020-08-06 18:42:48,509 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 79
# Billable seconds: 79

# %%
# AdaBoostClassifier
for data_desc in data_to_try:
    build_and_train_estimator(data_desc, 'AdaBoostClassifier')
# Out:
# model_name all-features-AdaBoostClassifier-1
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 18:57:21 Starting - Preparing the instances for training
# 2020-08-06 18:57:21 Downloading - Downloading input data
# 2020-08-06 18:57:21 Training - Training image download completed. Training in progress.
# 2020-08-06 18:57:21 Uploading - Uploading generated training model
# 2020-08-06 18:57:21 Completed - Training job completed2020-08-06 18:57:08,050 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 18:57:08,052 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:57:08,062 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 18:57:08,343 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 18:57:09,707 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:57:11,211 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:57:11,222 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 18:57:11,233 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "classifier": "AdaBoostClassifier"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-AdaBoostClassifier-1",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-1/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"AdaBoostClassifier"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-1/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"AdaBoostClassifier"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-AdaBoostClassifier-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","AdaBoostClassifier"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_CLASSIFIER=AdaBoostClassifier
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier AdaBoostClassifier
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-2-204-116.ec2.internal', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'all-features-AdaBoostClassifier-1', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/9c78ecf2-f700-4fd6-9e3d-6d577ca78ca4', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/ede897cb-be9d-464f-975a-469515b6748c', 'DMLC_INTERFACE': 'eth0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-adaboostclassifier-1', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/ede897cb-be9d-464f-975a-469515b6748c', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-AdaBoostClassifier-1', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"AdaBoostClassifier"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-1/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"AdaBoostClassifier"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-AdaBoostClassifier-1","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-1/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","AdaBoostClassifier"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_CLASSIFIER': 'AdaBoostClassifier', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "classifier": "\"AdaBoostClassifier\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-AdaBoostClassifier-1\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-1/source/sourcedir.tar.gz\""}
# hyperparameters: {"classifier": "AdaBoostClassifier"}
# data_desc training
# hyperparameters passed to model:  {}
# classification_report:  <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# accuracy: 0.92; recall: 0.8666666666666667; precision: 1.0; f1_score: 0.9285714285714286; inference_speed: 0.00039333343505859375
# 2020-08-06 18:57:12,680 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 81
# Billable seconds: 81

# %%
# DecisionTreeClassifier
for data_desc in data_to_try:
    for criterion in ['entropy', 'gini']:
        for min_samples_split in range(2, 5):
            build_and_train_estimator(
                data_desc,
                'DecisionTreeClassifier',
                count=2,
                criterion=criterion,
                min_samples_split=min_samples_split,
            )
# Out:
# model_name all-features-DecisionTreeClassifier-20583373-2
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 19:39:56 Starting - Preparing the instances for training
# 2020-08-06 19:39:56 Downloading - Downloading input data
# 2020-08-06 19:39:56 Training - Training image download completed. Training in progress.
# 2020-08-06 19:39:56 Uploading - Uploading generated training model
# 2020-08-06 19:39:56 Completed - Training job completed2020-08-06 19:39:43,439 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 19:39:43,441 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:39:43,450 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 19:39:43,734 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 19:39:45,170 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:39:45,181 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:39:45,191 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:39:45,202 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "criterion": "entropy",
#         "min_samples_split": 2,
#         "classifier": "DecisionTreeClassifier"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-DecisionTreeClassifier-20583373-2",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-20583373-2/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"DecisionTreeClassifier","criterion":"entropy","min_samples_split":2}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-20583373-2/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"DecisionTreeClassifier","criterion":"entropy","min_samples_split":2},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-DecisionTreeClassifier-20583373-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-20583373-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","DecisionTreeClassifier","--criterion","entropy","--min_samples_split","2"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_CRITERION=entropy
# SM_HP_MIN_SAMPLES_SPLIT=2
# SM_HP_CLASSIFIER=DecisionTreeClassifier
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier DecisionTreeClassifier --criterion entropy --min_samples_split 2
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-212-17.ec2.internal', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'DMLC_INTERFACE': 'eth0', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-decisiontreeclassifier-20583373-2', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/66680f66-7150-49aa-90df-d260b8601a9a', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_NAME': 'all-features-DecisionTreeClassifier-20583373-2', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/dbc2080e-3d45-4085-b962-8fcd2837ed86', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/dbc2080e-3d45-4085-b962-8fcd2837ed86', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-DecisionTreeClassifier-20583373-2', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"DecisionTreeClassifier","criterion":"entropy","min_samples_split":2}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-20583373-2/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"DecisionTreeClassifier","criterion":"entropy","min_samples_split":2},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-DecisionTreeClassifier-20583373-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-20583373-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","DecisionTreeClassifier","--criterion","entropy","--min_samples_split","2"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/outpu ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "criterion": "\"entropy\"", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "min_samples_split": "2", "classifier": "\"DecisionTreeClassifier\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-DecisionTreeClassifier-20583373-2\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-20583373-2/source/sourcedir.tar.gz\""}
# hyperparameters: {"criterion": "entropy", "min_samples_split": 2, "classifier": "DecisionTreeClassifier"}
# data_desc training
# hyperparameters passed to model:  {"criterion": "entropy", "min_samples_split": 2}
# classification_report:  <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# accuracy: 0.84; recall: 0.8666666666666667; precision: 0.8666666666666667; f1_score: 0.8666666666666667; inference_speed: 5.093574523925781e-05
# 2020-08-06 19:39:46,440 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 78
# Billable seconds: 78
# model_name all-features-DecisionTreeClassifier-17987551-2
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# model_name all-features-DecisionTreeClassifier-86389839-2
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# model_name all-features-DecisionTreeClassifier-10728801-2
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 19:44:30 Starting - Preparing the instances for training
# 2020-08-06 19:44:30 Downloading - Downloading input data
# 2020-08-06 19:44:30 Training - Training image download completed. Training in progress.
# 2020-08-06 19:44:30 Uploading - Uploading generated training model
# 2020-08-06 19:44:30 Completed - Training job completed2020-08-06 19:44:18,048 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 19:44:18,050 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:44:18,059 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 19:44:18,371 sagemaker-training-toolkit INFO     Installing dependencies from requirements.txt:
# /miniconda3/bin/python -m pip install -r requirements.txt
# Collecting joblib==0.16.0
#   Downloading joblib-0.16.0-py3-none-any.whl (300 kB)
# Installing collected packages: joblib
#   Attempting uninstall: joblib
#     Found existing installation: joblib 0.15.1
#     Uninstalling joblib-0.15.1:
#       Successfully uninstalled joblib-0.15.1
# Successfully installed joblib-0.16.0
# 2020-08-06 19:44:19,772 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:44:19,782 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:44:19,792 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 19:44:19,803 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "criterion": "gini",
#         "min_samples_split": 2,
#         "classifier": "DecisionTreeClassifier"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-DecisionTreeClassifier-10728801-2",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-10728801-2/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"DecisionTreeClassifier","criterion":"gini","min_samples_split":2}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-10728801-2/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"DecisionTreeClassifier","criterion":"gini","min_samples_split":2},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-DecisionTreeClassifier-10728801-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-10728801-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","DecisionTreeClassifier","--criterion","gini","--min_samples_split","2"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_CRITERION=gini
# SM_HP_MIN_SAMPLES_SPLIT=2
# SM_HP_CLASSIFIER=DecisionTreeClassifier
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier DecisionTreeClassifier --criterion gini --min_samples_split 2
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-206-84.ec2.internal', 'DMLC_INTERFACE': 'eth0', 'TRAINING_JOB_NAME': 'all-features-DecisionTreeClassifier-10728801-2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/9110fddc-12e0-40b2-b8cb-f4a585f8508b', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/95bf80fe-b3f6-4368-8877-06486e0b395d', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/9110fddc-12e0-40b2-b8cb-f4a585f8508b', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'AWS_REGION': 'us-east-1', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-decisiontreeclassifier-10728801-2', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-DecisionTreeClassifier-10728801-2', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"DecisionTreeClassifier","criterion":"gini","min_samples_split":2}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-10728801-2/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"DecisionTreeClassifier","criterion":"gini","min_samples_split":2},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-DecisionTreeClassifier-10728801-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-10728801-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","DecisionTreeClassifier","--criterion","gini","--min_samples_split","2"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/interme ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "criterion": "\"gini\"", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "min_samples_split": "2", "classifier": "\"DecisionTreeClassifier\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-DecisionTreeClassifier-10728801-2\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-DecisionTreeClassifier-10728801-2/source/sourcedir.tar.gz\""}
# hyperparameters: {"criterion": "gini", "min_samples_split": 2, "classifier": "DecisionTreeClassifier"}
# data_desc training
# hyperparameters passed to model:  {"criterion": "gini", "min_samples_split": 2}
# classification_report:  <class 'sklearn.tree._classes.DecisionTreeClassifier'>
# accuracy: 0.84; recall: 0.8666666666666667; precision: 0.8666666666666667; f1_score: 0.8666666666666667; inference_speed: 4.9505233764648434e-05
# 2020-08-06 19:44:21,088 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 87
# Billable seconds: 87
# model_name all-features-DecisionTreeClassifier-17062960-2
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.
# model_name all-features-DecisionTreeClassifier-57041587-2
# 's3_input' class will be renamed to 'TrainingInput' in SageMaker Python SDK v2.

# %% [markdown]
# ### Final Model

# %%
estimator, model_name = build_and_train_estimator(data_desc, 'AdaBoostClassifier', count=2, wait=True)
# Out:
# model_name all-features-AdaBoostClassifier-2
# This is not the latest supported version. If you would like to use version 0.23-1, please add framework_version=0.23-1 to your constructor.
# 2020-08-06 20:18:26 Starting - Preparing the instances for training
# 2020-08-06 20:18:26 Downloading - Downloading input data
# 2020-08-06 20:18:26 Training - Training image download completed. Training in progress.
# 2020-08-06 20:18:26 Uploading - Uploading generated training model
# 2020-08-06 20:18:26 Completed - Training job completed2020-08-06 20:18:14,201 sagemaker-training-toolkit INFO     Imported framework sagemaker_sklearn_container.training
# 2020-08-06 20:18:14,203 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 20:18:14,212 sagemaker_sklearn_container.training INFO     Invoking user training script.
# 2020-08-06 20:18:14,553 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 20:18:15,232 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 20:18:15,242 sagemaker-training-toolkit INFO     No GPUs detected (normal if no gpus installed)
# 2020-08-06 20:18:15,253 sagemaker-training-toolkit INFO     Invoking user script
#
# Training Env:
#
# {
#     "additional_framework_parameters": {},
#     "channel_input_dirs": {
#         "training": "/opt/ml/input/data/training"
#     },
#     "current_host": "algo-1",
#     "framework_module": "sagemaker_sklearn_container.training:main",
#     "hosts": [
#         "algo-1"
#     ],
#     "hyperparameters": {
#         "classifier": "AdaBoostClassifier"
#     },
#     "input_config_dir": "/opt/ml/input/config",
#     "input_data_config": {
#         "training": {
#             "TrainingInputMode": "File",
#             "S3DistributionType": "FullyReplicated",
#             "RecordWrapperType": "None"
#         }
#     },
#     "input_dir": "/opt/ml/input",
#     "is_master": true,
#     "job_name": "all-features-AdaBoostClassifier-2",
#     "log_level": 20,
#     "master_hostname": "algo-1",
#     "model_dir": "/opt/ml/model",
#     "module_dir": "s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-2/source/sourcedir.tar.gz",
#     "module_name": "train_and_deploy",
#     "network_interface_name": "eth0",
#     "num_cpus": 2,
#     "num_gpus": 0,
#     "output_data_dir": "/opt/ml/output/data",
#     "output_dir": "/opt/ml/output",
#     "output_intermediate_dir": "/opt/ml/output/intermediate",
#     "resource_config": {
#         "current_host": "algo-1",
#         "hosts": [
#             "algo-1"
#         ],
#         "network_interface_name": "eth0"
#     },
#     "user_entry_point": "train_and_deploy.py"
# }
#
# Environment variables:
#
# SM_HOSTS=["algo-1"]
# SM_NETWORK_INTERFACE_NAME=eth0
# SM_HPS={"classifier":"AdaBoostClassifier"}
# SM_USER_ENTRY_POINT=train_and_deploy.py
# SM_FRAMEWORK_PARAMS={}
# SM_RESOURCE_CONFIG={"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}
# SM_INPUT_DATA_CONFIG={"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}
# SM_OUTPUT_DATA_DIR=/opt/ml/output/data
# SM_CHANNELS=["training"]
# SM_CURRENT_HOST=algo-1
# SM_MODULE_NAME=train_and_deploy
# SM_LOG_LEVEL=20
# SM_FRAMEWORK_MODULE=sagemaker_sklearn_container.training:main
# SM_INPUT_DIR=/opt/ml/input
# SM_INPUT_CONFIG_DIR=/opt/ml/input/config
# SM_OUTPUT_DIR=/opt/ml/output
# SM_NUM_CPUS=2
# SM_NUM_GPUS=0
# SM_MODEL_DIR=/opt/ml/model
# SM_MODULE_DIR=s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-2/source/sourcedir.tar.gz
# SM_TRAINING_ENV={"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"AdaBoostClassifier"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-AdaBoostClassifier-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}
# SM_USER_ARGS=["--classifier","AdaBoostClassifier"]
# SM_OUTPUT_INTERMEDIATE_DIR=/opt/ml/output/intermediate
# SM_CHANNEL_TRAINING=/opt/ml/input/data/training
# SM_HP_CLASSIFIER=AdaBoostClassifier
# PYTHONPATH=/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib/python3.7/lib-dynload:/miniconda3/lib/python3.7/site-packages
#
# Invoking script with the following command:
#
# /miniconda3/bin/python train_and_deploy.py --classifier AdaBoostClassifier
#
#
# environment:  environ({'PATH': '/miniconda3/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin', 'HOSTNAME': 'ip-10-0-216-171.ec2.internal', 'ECS_CONTAINER_METADATA_URI': 'http://169.254.170.2/v3/2ce92fa1-a49a-4485-be6e-ece3da249ecb', 'AWS_EXECUTION_ENV': 'AWS_ECS_EC2', 'NVIDIA_VISIBLE_DEVICES': 'void', 'TRAINING_JOB_ARN': 'arn:aws:sagemaker:us-east-1:506779838262:training-job/all-features-adaboostclassifier-2', 'AWS_CONTAINER_CREDENTIALS_RELATIVE_URI': '/v2/credentials/c6f055ff-0eb1-4266-a586-814e739e5418', 'AWS_REGION': 'us-east-1', 'DMLC_INTERFACE': 'eth0', 'TRAINING_JOB_NAME': 'all-features-AdaBoostClassifier-2', 'ECS_CONTAINER_METADATA_URI_V4': 'http://169.254.170.2/v4/2ce92fa1-a49a-4485-be6e-ece3da249ecb', 'PYTHONDONTWRITEBYTECODE': '1', 'PYTHONUNBUFFERED': '1', 'PYTHONIOENCODING': 'UTF-8', 'LANG': 'C.UTF-8', 'LC_ALL': 'C.UTF-8', 'SAGEMAKER_SKLEARN_VERSION': '0.23-1', 'SAGEMAKER_TRAINING_MODULE': 'sagemaker_sklearn_container.training:main', 'SAGEMAKER_SERVING_MODULE': 'sagemaker_sklearn_container.serving:main', 'SKLEARN_MMS_CONFIG': '/home/model-server/config.properties', 'SM_INPUT': '/opt/ml/input', 'SM_INPUT_TRAINING_CONFIG_FILE': '/opt/ml/input/config/hyperparameters.json', 'SM_INPUT_DATA_CONFIG_FILE': '/opt/ml/input/config/inputdataconfig.json', 'SM_CHECKPOINT_CONFIG_FILE': '/opt/ml/input/config/checkpointconfig.json', 'SM_MODEL_DIR': '/opt/ml/model', 'TEMP': '/home/model-server/tmp', 'HOME': '/root', 'SAGEMAKER_JOB_NAME': 'all-features-AdaBoostClassifier-2', 'CURRENT_HOST': 'algo-1', 'SAGEMAKER_REGION': 'us-east-1', 'SM_HOSTS': '["algo-1"]', 'SM_NETWORK_INTERFACE_NAME': 'eth0', 'SM_HPS': '{"classifier":"AdaBoostClassifier"}', 'SM_USER_ENTRY_POINT': 'train_and_deploy.py', 'SM_FRAMEWORK_PARAMS': '{}', 'SM_RESOURCE_CONFIG': '{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"}', 'SM_INPUT_DATA_CONFIG': '{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}}', 'SM_OUTPUT_DATA_DIR': '/opt/ml/output/data', 'SM_CHANNELS': '["training"]', 'SM_CURRENT_HOST': 'algo-1', 'SM_MODULE_NAME': 'train_and_deploy', 'SM_LOG_LEVEL': '20', 'SM_FRAMEWORK_MODULE': 'sagemaker_sklearn_container.training:main', 'SM_INPUT_DIR': '/opt/ml/input', 'SM_INPUT_CONFIG_DIR': '/opt/ml/input/config', 'SM_OUTPUT_DIR': '/opt/ml/output', 'SM_NUM_CPUS': '2', 'SM_NUM_GPUS': '0', 'SM_MODULE_DIR': 's3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-2/source/sourcedir.tar.gz', 'SM_TRAINING_ENV': '{"additional_framework_parameters":{},"channel_input_dirs":{"training":"/opt/ml/input/data/training"},"current_host":"algo-1","framework_module":"sagemaker_sklearn_container.training:main","hosts":["algo-1"],"hyperparameters":{"classifier":"AdaBoostClassifier"},"input_config_dir":"/opt/ml/input/config","input_data_config":{"training":{"RecordWrapperType":"None","S3DistributionType":"FullyReplicated","TrainingInputMode":"File"}},"input_dir":"/opt/ml/input","is_master":true,"job_name":"all-features-AdaBoostClassifier-2","log_level":20,"master_hostname":"algo-1","model_dir":"/opt/ml/model","module_dir":"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-2/source/sourcedir.tar.gz","module_name":"train_and_deploy","network_interface_name":"eth0","num_cpus":2,"num_gpus":0,"output_data_dir":"/opt/ml/output/data","output_dir":"/opt/ml/output","output_intermediate_dir":"/opt/ml/output/intermediate","resource_config":{"current_host":"algo-1","hosts":["algo-1"],"network_interface_name":"eth0"},"user_entry_point":"train_and_deploy.py"}', 'SM_USER_ARGS': '["--classifier","AdaBoostClassifier"]', 'SM_OUTPUT_INTERMEDIATE_DIR': '/opt/ml/output/intermediate', 'SM_CHANNEL_TRAINING': '/opt/ml/input/data/training', 'SM_HP_CLASSIFIER': 'AdaBoostClassifier', 'PYTHONPATH': '/opt/ml/code:/miniconda3/bin:/miniconda3/lib/python37.zip:/miniconda3/lib/python3.7:/miniconda3/lib ...
# loading hyperparameters
# hyperparameters initial: {"sagemaker_container_log_level": "20", "sagemaker_program": "\"train_and_deploy.py\"", "sagemaker_enable_cloudwatch_metrics": "false", "classifier": "\"AdaBoostClassifier\"", "sagemaker_region": "\"us-east-1\"", "sagemaker_job_name": "\"all-features-AdaBoostClassifier-2\"", "sagemaker_submit_directory": "\"s3://sagemaker-us-east-1-506779838262/P4_plagiarism_detection/model-data/all-features/all-features-AdaBoostClassifier-2/source/sourcedir.tar.gz\""}
# hyperparameters: {"classifier": "AdaBoostClassifier"}
# hyperparameters passed to model:  {}
# classification_report:  <class 'sklearn.ensemble._weight_boosting.AdaBoostClassifier'>
# accuracy: 0.92; recall: 0.8666666666666667; precision: 1.0; f1_score: 0.9285714285714286; inference_speed: 0.0002769947052001953
# 2020-08-06 20:18:16,681 sagemaker-training-toolkit INFO     Reporting training SUCCESS
# Training seconds: 80
# Billable seconds: 80

# %% [markdown]
# ## EXERCISE: Deploy the trained model
#
# After training, deploy your model to create a `predictor`. If you're using a PyTorch model, you'll need to create a trained `PyTorchModel` that accepts the trained `<model>.model_data` as an input parameter and points to the provided `source_pytorch/predict.py` file as an entry point.
#
# To deploy a trained model, you'll use `<model>.deploy`, which takes in two arguments:
# * **initial_instance_count**: The number of deployed instances (1).
# * **instance_type**: The type of SageMaker instance for deployment.
#
# Note: If you run into an instance error, it may be because you chose the wrong training or deployment instance_type. It may help to refer to your previous exercise code to see which types of instances we used.

# %%
# %%time
# deploy your model to create a predictor
predictor = estimator.deploy(
    initial_instance_count=1,
    instance_type=DEPLOY_INSTANCE,
    endpoint_name=model_name + '-ep'
)
# Out:
# Parameter image will be renamed to image_uri in SageMaker Python SDK v2.
# -----------------!CPU times: user 384 ms, sys: 41.9 ms, total: 426 ms
# Wall time: 8min 36s

# %% [markdown]
# ---
# # Evaluating Your Model
#
# Once your model is deployed, you can see how it performs when applied to our test data.
#
# The provided cell below, reads in the test data, assuming it is stored locally in `data_dir` and named `test.csv`. The labels and features are extracted from the `.csv` file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

# read in test data, assuming it is stored locally
test_data = pd.read_csv(os.path.join(OUTPUT_DIR / data_to_try[0], "test.csv"), header=None, names=None)

# labels are in the first column
test_labels = test_data.iloc[:, 0]
test_features = test_data.iloc[:, 1:]

# %% [markdown]
# ## EXERCISE: Determine the accuracy of your model
#
# Use your deployed `predictor` to generate predicted, class labels for the test data. Compare those to the *true* labels, `test_y`, and calculate the accuracy as a value between 0 and 1.0 that indicates the fraction of test data that your model classified correctly. You may use [sklearn.metrics](https://scikit-learn.org/stable/modules/classes.html#module-sklearn.metrics) for this calculation.
#
# **To pass this project, your model should get at least 90% test accuracy.**

# %%
# First: generate predicted, class labels
# noinspection PyTypeChecker
predict_labels: np.ndarray = predictor.predict(test_features)  # `.predict` doesn't have a return type defined

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# test that your model generates the correct number of labels
assert len(predict_labels) == len(test_labels), 'Unexpected number of predictions.'
print('Test passed!')
# Out:
# Test passed!

# %%
# Second: calculate the test accuracy
accuracy = accuracy_score(predict_labels, test_labels)

print(accuracy)
# Out:
# 0.92

# %% [markdown]
# ### Question 1: How many false positives and false negatives did your model produce, if any? And why do you think this is?

# %% [markdown]
# **Answer**:
#
# The count of false positives and false negatives are in the next cell.
#
# > And why do you think this is?
#
# This models accuracy is not 100%.
# This means that it has to have at least some incorrect (aka false) results.
#
# False negatives are when a positive value is predicted to be a negative value. This is a

# %%
test_labels = test_labels.to_numpy().astype(bool)
predict_labels = predict_labels.astype(bool)

# %%
true_positives = (predict_labels & test_labels).sum()
false_positives = (predict_labels & ~test_labels).sum()
true_negatives = (~predict_labels & ~test_labels).sum()
false_negatives = (~predict_labels & test_labels).sum()
len(test_labels), true_positives, false_positives, true_negatives, false_negatives
# Out:
# (25, 13, 0, 10, 2)

# %%
assert (true_positives + false_positives + true_negatives + false_negatives) == len(test_labels), \
    'All cases should sum to the number of instances'
assert true_positives + false_positives == predict_labels.sum(), \
    'number of positives (true + false) should equal the number of positives in the predict set'
assert true_negatives + false_negatives == (len(predict_labels) - predict_labels.sum()), \
    'number of negatives (true + false) should equal the number of negatives in the predict set'
assert true_positives + false_negatives == test_labels.sum(), \
    'true pos + false neg should equal the number of positives in the test set'
assert true_negatives + false_positives == (len(test_labels) - test_labels.sum()), \
    'true neg + false pos should equal the number of negatives in the test set'

print('number of false positives', false_positives)
print('number of false negatives', false_negatives)
# Out:
# number of false positives 0
# number of false negatives 2

# %% [markdown]
# ### Question 2: How did you decide on the type of model to use?

# %% [markdown]
# **Answer**:
#
# We were looking for a 90%+ accuracy score.
# A number of scikit-learn models can achieve this level of accuracy on a dataset this size with fairly low computation requirements.
# Given the type of data, Naïve Bayes, SVM, or a Decision Tree model seemed likely to work.
# Given all this information, a search of the given models with stopping at 90% accuracy seemed like the fastest way to finish the requirements.
#
# Search criteria:
# - features
#     - start with all features
#     - remove low correlated features in a second and third round
# - models & parameters:
#     - Naïve Bayes
#         - GaussianNB
#     - SVM
#         - kernel: 'rbf', 'linear', 'poly', or 'sigmoid'
#     - Ada Boost
#         - Default
#     - Random Forest
#         - criterion: 'entropy', 'gini'
#         - min_samples_split: 2, 3, 4, 5
# - stopping conditions:
#     - more than 90% accuracy
#     - more than 3 hours spent in training
# - continue iterating on model, parameters, and features until a stopping condition is met
#
# These search parameters found a model that achieved over 90% accuracy in the first hour of training, so much of the search was not completed.
# In a work environment if we were looking for an accuracy of 90% and achieved it we would stop our search and start the deployment process in order to gain as much benefit from the improvement as possible.
# After a round of deployment and verifying the results we would most-likely circle back on improving this model further since it's most likely possible to get a higher accuracy with it's most likely possible to get a higher accuracy with a little more work.
#
# If this search hadn't found the results we were looking for it would have given us a lot of information to point us in a new direction for where to go next
#
# #### Ways to improve:
#
# Use a hyperparameter tuning job:
#
# Ideally the hyperparameter tuning solution from sagemaker would have been used.
# This would have required implementing a container that could be used with the hyperparameter tuning job and defining a tuning job per model.
# A hyperparameter tuning job would have searched the solution space more effectively and could have been used to avoid the training instance limit.
# This would have been more efficient than looping over the solution space.

# %% [markdown]
# ----
# ## EXERCISE: Clean up Resources
#
# After you're done evaluating your model, **delete your model endpoint**. You can do this with a call to `.delete_endpoint()`. You need to show, in this notebook, that the endpoint was deleted. Any other resources, you may delete from the AWS console, and you will find more instructions on cleaning up all your resources, below.

# %%
# uncomment and fill in the line below!
predictor.delete_endpoint()
